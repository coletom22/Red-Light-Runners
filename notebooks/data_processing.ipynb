# %% [markdown]
# # This notebook can be used to process the dashcam data
# ## Data Process
# 1. Convert videos to frames. Store in `data/images/frames/`
# 2. Iterate over data in two locations: `data/images/frames` and `data/images/augmented` with 3 options:
#     1. Label current frame:
#         * Copies original image as a `768 X 448`
#         * Draw bounding boxes
#         * Save two formats of labels: `labels/viewing/` and `labels/formatted/`
#         * Move `768 X 448` image to `data/images/processed/`
#         * Move original image to `data/images/frames_original`
#     2. Select frame for augmenting:
#         * Move original image to `data/images/for_augmenting`
#     3. Delete frame from dataset

# %%
import os
import sys
import cv2
sys.path.append(os.path.abspath('../src'))
import utils
import shutil

# %%
# Directories
trimmed_video_dir = '../data/videos/trimmed'

processed_video_dir = '../data/videos/processed'

frame_dir = '../data/images/frames'

# %%
videos = os.listdir(trimmed_video_dir)

num_videos = int(input(f"Enter the number of videos to convert to frames 0-{len(videos)}"))

if num_videos > len(videos):
    num_videos = len(videos)

if num_videos < 0:
    num_videos = 0

print("\n".join(videos[:num_videos]))

# %%
for video in videos[:num_videos]:
    
    video_name = os.path.splitext(os.path.basename(video))[0]

    video_path = f"{trimmed_video_dir}/{video}"

    utils.video_to_frames(video_path, frame_dir, video_name)

    shutil.move(video_path, f"{processed_video_dir}/{video}")

# %%
import screeninfo

# Get second monitor details
monitors = screeninfo.get_monitors()
if len(monitors) > 1:
    second_monitor = monitors[1]  # Assuming second monitor is at index 1
    x_offset, y_offset = second_monitor.x, second_monitor.y
    screen_width, screen_height = second_monitor.width, second_monitor.height
else:
    x_offset, y_offset = 0, 0  # Default to primary monitor
    screen_width, screen_height = monitors[0].width, monitors[0].height  # Primary monitor size

# Reduce size slightly to keep windowed view
window_width = int(screen_width * 0.95)  # 95% of the screen width
window_height = int(screen_height * 0.95)  # 95% of the screen height

# Center the window with some margin
window_x = x_offset + (screen_width - window_width) // 2
window_y = y_offset + (screen_height - window_height) // 2

# %%
# Standardized image width/height
IMAGE_WIDTH, IMAGE_HEIGHT = 768, 448

# Iterate over every n-th frame
STEP = 10
# Directory to place images once processed (resized and annotated)
processed_dir = "../data/images/processed"

# Directory to place original images
original_dir = "../data/images/frames_original"

# Directory to place images for augmenting
augmenting_dir = "../data/images/for_augmenting"

# Color mapping based on key presses
color_mapping = {
    ord("1"): (0, 255, 0),   # Green
    ord("2"): (0, 0, 255),   # Red
    ord("3"): (0, 255, 255), # Yellow
}

# Label mapping based on colors
label_mapping = {
    (0, 255, 0): "Green Light",
    (0, 0, 255): "Red Light",
    (0, 255, 255): "Yellow Light"
}

# Class mapping based on label (for YOLO format that uses int instead of str)
class_mapping = {
    "Green Light": 1,
    "Red Light": 2,
    "Yellow Light": 3
}

# Exit labelling variable
exit = False

# Mouse callback function
def draw_rectangle_with_drag(event, x, y, flags, param):
    global ix, iy, drawing, img_copy, img, current_color

    # Left clicking starts a drawing event if the user is not currently drawing
    if event == cv2.EVENT_LBUTTONDOWN and not drawing:  
        drawing = True # event status is drawing
        ix, iy = x, y # anchor point for the first corner of the rectangle
        img_copy = img.copy()  # reset copy when starting a new rectangle

    # When the cursor is moving and we are in drawing status display adjusted size of rectangle based on cursor location
    elif event == cv2.EVENT_MOUSEMOVE and drawing:  
        img_copy = img.copy()  # reset to avoid multiple overlapping rectangles
        cv2.rectangle(img_copy, (ix, iy), (x, y), current_color, 1) # drawing rectangle from ix, iy to current cursor position

    # Left click when we are already drawing places the rectangle where the cursor is located during the click
    elif event == cv2.EVENT_LBUTTONDOWN and drawing:  
        drawing = False # reset event status to not drawing
        cv2.rectangle(img, (ix, iy), (x, y), current_color, 1)  # draw on final image
        annotations.append({
            "x1": min(ix, x),
            "x2": max(ix, x),
            "y1": min(iy, y),
            "y2": max(iy, y),
            "color_code": current_color,
            "color": label_mapping[current_color],
            "class": class_mapping[label_mapping[current_color]]
        }) # appends a map of values needed for documentation min/max x and y coordinates, color codes, colors, and class
        
        redraw_rectangles()  # for view consistency

# redraws all the rectangles from the list of annotations
def redraw_rectangles():
    global img, img_copy
    img = resized_img.copy()  # reset to the resized image
    for ann in annotations:
        cv2.rectangle(img, 
                      (ann["x1"], ann["y1"]), 
                      (ann["x2"], ann["y2"]), 
                      ann["color_code"], 1) # draws each rectangle
        
    img_copy = img.copy()  # Update the display copy

# Iterate over each file in the frame dir
files = os.listdir(frame_dir)
for i in range(0, len(files), STEP):
    filename = files[i]

    if exit:
        break

    file_path = os.path.join(frame_dir, filename)

    if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
        # Load image
        original_img = cv2.imread(file_path)  # keep original image
        if original_img is None:
            raise FileNotFoundError("Image not found. Check the file path.")
        
        # Resize the image to a uniform size
        resized_img = cv2.resize(original_img, (IMAGE_WIDTH, IMAGE_HEIGHT))

        # Initialize working images
        img = resized_img.copy()   # Active drawing image
        img_copy = img.copy()      # Image copy for real-time updates

        # Anchor variables
        ix, iy = -1, -1
        drawing = False
        current_color = (0, 255, 0)  # Default: Green

        # Prepare annotation file
        img_filename = os.path.basename(file_path)
        print(img_filename)
        print(os.path.splitext(img_filename)[0])
        text_filename = os.path.splitext(img_filename)[0] + ".txt"
        
        # Viewing annotation file
        viewing_annotation_path = f"../data/labels/viewing/viewing_{text_filename}"
        # Formatted annotation file
        yolo_annotations_path = f'../data/labels/formatted/{text_filename}'


        # List to store dicts of annotations
        annotations = []
        # Create window and set mouse callback
        window_name = f"Label Data: {filename}"
        cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)  # Allow resizing
        cv2.resizeWindow(window_name, window_width, window_height)  # Set to 95% of screen size
        cv2.moveWindow(window_name, window_x, window_y)  # Center it on the second monitor
        cv2.setMouseCallback(window_name, draw_rectangle_with_drag)

        # Display loop
        while True:
            cv2.imshow(window_name, img_copy)  # Show dynamic updates
            key = cv2.waitKey(10) & 0xFF
            
            # Press 'Esc' to exit
            if key == 27:
                exit = True
                break
            
            # Press 's' to save annotations
            elif key == ord("s"):

                # Open viewing text file, iterate over annotations and write to file
                with open(viewing_annotation_path, 'w') as viewing_file:
                    for annotation in annotations:
                        viewing_file.write(f"{annotation}\n")
                print(f"Viewing annotations saved to {viewing_annotation_path}")
                
                # Convert annotations to yolo format
                yolo_annotations = utils.viewing_to_yolo(annotations, IMAGE_WIDTH, IMAGE_HEIGHT)

                # Open yolo text file, iterate over annotations and write to file
                with open(yolo_annotations_path, 'w') as yolo_file:
                    for yolo_ann in yolo_annotations:
                        yolo_str = ", ".join(map(str, yolo_ann))  # Convert each item to string and join with commas
                        yolo_file.write(f"{yolo_str}\n")  # Write formatted string to file
                print(f"YOLO annotations saved to {yolo_annotations_path}")


                # Open processed_dir and write resized image to the directory
                os.makedirs(processed_dir, exist_ok=True)
                processed_path = os.path.join(processed_dir, os.path.basename(file_path))
                cv2.imwrite(processed_path, resized_img)
                print(f"Moved {filename} -> {processed_path}")

                os.makedirs(original_dir, exist_ok=True)
                original_path = os.path.join(original_dir, os.path.basename(file_path))
                shutil.move(file_path, original_path)
                break


            # Press 'a' to move frame to data/images/for_augmenting
            elif key == ord('a'):
                for_augmenting_path = os.path.join(augmenting_dir, os.path.basename(file_path))
                shutil.move(file_path, for_augmenting_path)
                print(f"Moved {filename} -> {for_augmenting_path}")
                
            # Change rectangle color based on number key
            elif key in color_mapping:  
                current_color = color_mapping[key]
                print(f"Class changed to: {label_mapping[color_mapping[key]]}")
            
            # Press 'z' to undo last rectangle
            elif key == ord("z") and annotations: 
                annotations.pop()  # remove last rectangle
                redraw_rectangles()  # reset image and redraw remaining rectangles
                print("Last rectangle removed!")

        cv2.destroyAllWindows()
cv2.destroyAllWindows()
# Out:
# Class changed to: Yellow Light
# Class changed to: Green Light
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_000389.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_000389.txt
# Moved 20250222_152040M_000389.jpg -> ../data/images/processed\20250222_152040M_000389.jpg
# Class changed to: Yellow Light
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_000399.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_000399.txt
# Moved 20250222_152040M_000399.jpg -> ../data/images/processed\20250222_152040M_000399.jpg
# Class changed to: Yellow Light
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_000409.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_000409.txt
# Moved 20250222_152040M_000409.jpg -> ../data/images/processed\20250222_152040M_000409.jpg
# Class changed to: Yellow Light
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_000419.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_000419.txt
# Moved 20250222_152040M_000419.jpg -> ../data/images/processed\20250222_152040M_000419.jpg
# Class changed to: Yellow Light
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_000429.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_000429.txt
# Moved 20250222_152040M_000429.jpg -> ../data/images/processed\20250222_152040M_000429.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_000439.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_000439.txt
# Moved 20250222_152040M_000439.jpg -> ../data/images/processed\20250222_152040M_000439.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_000449.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_000449.txt
# Moved 20250222_152040M_000449.jpg -> ../data/images/processed\20250222_152040M_000449.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_000459.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_000459.txt
# Moved 20250222_152040M_000459.jpg -> ../data/images/processed\20250222_152040M_000459.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_000469.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_000469.txt
# Moved 20250222_152040M_000469.jpg -> ../data/images/processed\20250222_152040M_000469.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_000479.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_000479.txt
# Moved 20250222_152040M_000479.jpg -> ../data/images/processed\20250222_152040M_000479.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_000489.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_000489.txt
# Moved 20250222_152040M_000489.jpg -> ../data/images/processed\20250222_152040M_000489.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_000499.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_000499.txt
# Moved 20250222_152040M_000499.jpg -> ../data/images/processed\20250222_152040M_000499.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_000509.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_000509.txt
# Moved 20250222_152040M_000509.jpg -> ../data/images/processed\20250222_152040M_000509.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_000519.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_000519.txt
# Moved 20250222_152040M_000519.jpg -> ../data/images/processed\20250222_152040M_000519.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_000529.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_000529.txt
# Moved 20250222_152040M_000529.jpg -> ../data/images/processed\20250222_152040M_000529.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_000539.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_000539.txt
# Moved 20250222_152040M_000539.jpg -> ../data/images/processed\20250222_152040M_000539.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_000549.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_
jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001419.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001419.txt
# Moved 20250222_152040M_001419.jpg -> ../data/images/processed\20250222_152040M_001419.jpg
# Class changed to: Red Light
# Class changed to: Green Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001429.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001429.txt
# Moved 20250222_152040M_001429.jpg -> ../data/images/processed\20250222_152040M_001429.jpg
# Class changed to: Red Light
# Class changed to: Green Light
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001439.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001439.txt
# Moved 20250222_152040M_001439.jpg -> ../data/images/processed\20250222_152040M_001439.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001449.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001449.txt
# Moved 20250222_152040M_001449.jpg -> ../data/images/processed\20250222_152040M_001449.jpg
# Class changed to: Red Light
# Class changed to: Green Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001459.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001459.txt
# Moved 20250222_152040M_001459.jpg -> ../data/images/processed\20250222_152040M_001459.jpg
# Class changed to: Red Light
# Class changed to: Green Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001469.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001469.txt
# Moved 20250222_152040M_001469.jpg -> ../data/images/processed\20250222_152040M_001469.jpg
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001479.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001479.txt
# Moved 20250222_152040M_001479.jpg -> ../data/images/processed\20250222_152040M_001479.jpg
# Class changed to: Red Light
# Class changed to: Green Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001489.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001489.txt
# Moved 20250222_152040M_001489.jpg -> ../data/images/processed\20250222_152040M_001489.jpg
# Last rectangle removed!
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001499.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001499.txt
# Moved 20250222_152040M_001499.jpg -> ../data/images/processed\20250222_152040M_001499.jpg
# Class changed to: Red Light
# Class changed to: Green Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001509.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001509.txt
# Moved 20250222_152040M_001509.jpg -> ../data/images/processed\20250222_152040M_001509.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001519.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001519.txt
# Moved 20250222_152040M_001519.jpg -> ../data/images/processed\20250222_152040M_001519.jpg
# Class changed to: Red Light
# Class changed to: Green Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001529.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001529.txt
# Moved 20250222_152040M_001529.jpg -> ../data/images/processed\20250222_152040M_001529.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001539.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001539.txt
# Moved 20250222_152040M_001539.jpg -> ../data/images/processed\20250222_152040M_001539.jpg
# Class changed to: Red Light
# Class changed to: Green Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001549.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001549.txt
# Moved 20250222_152040M_001549.jpg -> ../data/images/processed\20250222_152040M_001549.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001559.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001559.txt
# Moved 20250222_152040M_001559.jpg -> ../data/images/processed\20250222_152040M_001559.jpg
# Class changed to: Red Light
# Class changed to: Green Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001569.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001569.txt
# Moved 20250222_152040M_001569.jpg -> ../data/images/processed\20250222_152040M_001569.jpg
# Class changed to: Red Light
# Class changed to: Green Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001579.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001579.txt
# Moved 20250222_152040M_001579.jpg -> ../data/images/processed\20250222_152040M_001579.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001589.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001589.txt
# Moved 20250222_152040M_001589.jpg -> ../data/images/processed\20250222_152040M_001589.jpg
# Class changed to: Red Light
# Class changed to: Green Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001599.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001599.txt
# Moved 20250222_152040M_001599.jpg -> ../data/images/processed\20250222_152040M_001599.jpg
# Class changed to: Red Light
# Class changed to: Green Light
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001609.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001609.txt
# Moved 20250222_152040M_001609.jpg -> ../data/images/processed\20250222_152040M_001609.jpg
# Class changed to: Red Light
# Class changed to: Green Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001619.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001619.txt
# Moved 20250222_152040M_001619.jpg -> ../data/images/processed\20250222_152040M_001619.jpg
# Class changed to: Red Light
# Class changed to: Green Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001629.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001629.txt
# Moved 20250222_152040M_001629.jpg -> ../data/images/processed\20250222_152040M_001629.jpg
# Class changed to: Red Light
# Class changed to: Green Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001639.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001639.txt
# Moved 20250222_152040M_001639.jpg -> ../data/images/processed\20250222_152040M_001639.jpg
# Class changed to: Yellow Light
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001649.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001649.txt
# Moved 20250222_152040M_001649.jpg -> ../data/images/processed\20250222_152040M_001649.jpg
# Class changed to: Red Light
# Class changed to: Yellow Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001659.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001659.txt
# Moved 20250222_152040M_001659.jpg -> ../data/images/processed\20250222_152040M_001659.jpg
# Class changed to: Yellow Light
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001669.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001669.txt
# Moved 20250222_152040M_001669.jpg -> ../data/images/processed\20250222_152040M_001669.jpg
# Class changed to: Red Light
# Class changed to: Yellow Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001679.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001679.txt
# Moved 20250222_152040M_001679.jpg -> ../data/images/processed\20250222_152040M_001679.jpg
# Class changed to: Yellow Light
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001689.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001689.txt
# Moved 20250222_152040M_001689.jpg -> ../data/images/processed\20250222_152040M_001689.jpg
# Class changed to: Red Light
# Class changed to: Yellow Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001699.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001699.txt
# Moved 20250222_152040M_001699.jpg -> ../data/images/processed\20250222_152040M_001699.jpg
# Class changed to: Yellow Light
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001709.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001709.txt
# Moved 20250222_152040M_001709.jpg -> ../data/images/processed\20250222_152040M_001709.jpg
# Class changed to: Red Light
# Class changed to: Yellow Light
# Class changed to: Yellow Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001719.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001719.txt
# Moved 20250222_152040M_001719.jpg -> ../data/images/processed\20250222_152040M_001719.jpg
# Class changed to: Yellow Light
# Class changed to: Red Light
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001729.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001729.txt
# Moved 20250222_152040M_001729.jpg -> ../data/images/processed\20250222_152040M_001729.jpg
# Class changed to: Red Light
# Class changed to: Yellow Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001739.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001739.txt
# Moved 20250222_152040M_001739.jpg -> ../data/images/processed\20250222_152040M_001739.jpg
# Class changed to: Yellow Light
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001749.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001749.txt
# Moved 20250222_152040M_001749.jpg -> ../data/images/processed\20250222_152040M_001749.jpg
# Class changed to: Yellow Light
# Class changed to: Red Light
# Class changed to: Yellow Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001759.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001759.txt
# Moved 20250222_152040M_001759.jpg -> ../data/images/processed\20250222_152040M_001759.jpg
# Class changed to: Yellow Light
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001769.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001769.txt
# Moved 20250222_152040M_001769.jpg -> ../data/images/processed\20250222_152040M_001769.jpg
# Class changed to: Red Light
# Class changed to: Yellow Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001779.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001779.txt
# Moved 20250222_152040M_001779.jpg -> ../data/images/processed\20250222_152040M_001779.jpg
# Class changed to: Yellow Light
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001789.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001789.txt
# Moved 20250222_152040M_001789.jpg -> ../data/images/processed\20250222_152040M_001789.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001799.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001799.txt
# Moved 20250222_152040M_001799.jpg -> ../data/images/processed\20250222_152040M_001799.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001809.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001809.txt
# Moved 20250222_152040M_001809.jpg -> ../data/images/processed\20250222_152040M_001809.jpg
# Class changed to: Red Light
# Last rectangle removed!
# Last rectangle removed!
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001819.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001819.txt
# Moved 20250222_152040M_001819.jpg -> ../data/images/processed\20250222_152040M_001819.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001829.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001829.txt
# Moved 20250222_152040M_001829.jpg -> ../data/images/processed\20250222_152040M_001829.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001839.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001839.txt
# Moved 20250222_152040M_001839.jpg -> ../data/images/processed\20250222_152040M_001839.jpg
# Class changed to: Red Light
# Last rectangle removed!
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001849.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001849.txt
# Moved 20250222_152040M_001849.jpg -> ../data/images/processed\20250222_152040M_001849.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001859.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001859.txt
# Moved 20250222_152040M_001859.jpg -> ../data/images/processed\20250222_152040M_001859.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001869.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001869.txt
# Moved 20250222_152040M_001869.jpg -> ../data/images/processed\20250222_152040M_001869.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001879.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001879.txt
# Moved 20250222_152040M_001879.jpg -> ../data/images/processed\20250222_152040M_001879.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001889.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001889.txt
# Moved 20250222_152040M_001889.jpg -> ../data/images/processed\20250222_152040M_001889.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001899.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001899.txt
# Moved 20250222_152040M_001899.jpg -> ../data/images/processed\20250222_152040M_001899.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001909.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001909.txt
# Moved 20250222_152040M_001909.jpg -> ../data/images/processed\20250222_152040M_001909.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001919.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001919.txt
# Moved 20250222_152040M_001919.jpg -> ../data/images/processed\20250222_152040M_001919.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001929.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_001929.txt
# Moved 20250222_152040M_001929.jpg -> ../data/images/processed\20250222_152040M_001929.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_001939.txt
# ...
# Moved 20250222_152040M_003709.jpg -> ../data/images/processed\20250222_152040M_003709.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003719.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003719.txt
# Moved 20250222_152040M_003719.jpg -> ../data/images/processed\20250222_152040M_003719.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003729.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003729.txt
# Moved 20250222_152040M_003729.jpg -> ../data/images/processed\20250222_152040M_003729.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003739.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003739.txt
# Moved 20250222_152040M_003739.jpg -> ../data/images/processed\20250222_152040M_003739.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003749.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003749.txt
# Moved 20250222_152040M_003749.jpg -> ../data/images/processed\20250222_152040M_003749.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003759.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003759.txt
# Moved 20250222_152040M_003759.jpg -> ../data/images/processed\20250222_152040M_003759.jpg
# Class changed to: Red Light
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003769.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003769.txt
# Moved 20250222_152040M_003769.jpg -> ../data/images/processed\20250222_152040M_003769.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003779.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003779.txt
# Moved 20250222_152040M_003779.jpg -> ../data/images/processed\20250222_152040M_003779.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003789.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003789.txt
# Moved 20250222_152040M_003789.jpg -> ../data/images/processed\20250222_152040M_003789.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003799.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003799.txt
# Moved 20250222_152040M_003799.jpg -> ../data/images/processed\20250222_152040M_003799.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003809.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003809.txt
# Moved 20250222_152040M_003809.jpg -> ../data/images/processed\20250222_152040M_003809.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003819.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003819.txt
# Moved 20250222_152040M_003819.jpg -> ../data/images/processed\20250222_152040M_003819.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003829.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003829.txt
# Moved 20250222_152040M_003829.jpg -> ../data/images/processed\20250222_152040M_003829.jpg
# Class changed to: Red Light
# Class changed to: Green Light
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003839.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003839.txt
# Moved 20250222_152040M_003839.jpg -> ../data/images/processed\20250222_152040M_003839.jpg
# Class changed to: Green Light
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003849.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003849.txt
# Moved 20250222_152040M_003849.jpg -> ../data/images/processed\20250222_152040M_003849.jpg
# Class changed to: Green Light
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003859.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003859.txt
# Moved 20250222_152040M_003859.jpg -> ../data/images/processed\20250222_152040M_003859.jpg
# Class changed to: Red Light
# Class changed to: Green Light
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003869.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003869.txt
# Moved 20250222_152040M_003869.jpg -> ../data/images/processed\20250222_152040M_003869.jpg
# Class changed to: Green Light
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003879.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003879.txt
# Moved 20250222_152040M_003879.jpg -> ../data/images/processed\20250222_152040M_003879.jpg
# Class changed to: Green Light
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003889.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003889.txt
# Moved 20250222_152040M_003889.jpg -> ../data/images/processed\20250222_152040M_003889.jpg
# Class changed to: Red Light
# Class changed to: Green Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003899.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003899.txt
# Moved 20250222_152040M_003899.jpg -> ../data/images/processed\20250222_152040M_003899.jpg
# Class changed to: Green Light
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003909.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003909.txt
# Moved 20250222_152040M_003909.jpg -> ../data/images/processed\20250222_152040M_003909.jpg
# Class changed to: Green Light
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003919.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003919.txt
# Moved 20250222_152040M_003919.jpg -> ../data/images/processed\20250222_152040M_003919.jpg
# Class changed to: Red Light
# Class changed to: Green Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003929.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003929.txt
# Moved 20250222_152040M_003929.jpg -> ../data/images/processed\20250222_152040M_003929.jpg
# Class changed to: Green Light
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003939.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003939.txt
# Moved 20250222_152040M_003939.jpg -> ../data/images/processed\20250222_152040M_003939.jpg
# Class changed to: Red Light
# Class changed to: Green Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003949.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003949.txt
# Moved 20250222_152040M_003949.jpg -> ../data/images/processed\20250222_152040M_003949.jpg
# Class changed to: Green Light
# Class changed to: Red Light
# Class changed to: Green Light
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003959.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003959.txt
# Moved 20250222_152040M_003959.jpg -> ../data/images/processed\20250222_152040M_003959.jpg
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003969.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003969.txt
# Moved 20250222_152040M_003969.jpg -> ../data/images/processed\20250222_152040M_003969.jpg
# Class changed to: Red Light
# Class changed to: Green Light
# Class changed to: Red Light
# Class changed to: Green Light
# Class changed to: Green Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003979.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003979.txt
# Moved 20250222_152040M_003979.jpg -> ../data/images/processed\20250222_152040M_003979.jpg
# Class changed to: Green Light
# Class changed to: Red Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003989.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003989.txt
# Moved 20250222_152040M_003989.jpg -> ../data/images/processed\20250222_152040M_003989.jpg
# Class changed to: Red Light
# Class changed to: Green Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_003999.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_003999.txt
# Moved 20250222_152040M_003999.jpg -> ../data/images/processed\20250222_152040M_003999.jpg
# Class changed to: Green Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_004009.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_004009.txt
# Moved 20250222_152040M_004009.jpg -> ../data/images/processed\20250222_152040M_004009.jpg
# Class changed to: Green Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_004019.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_004019.txt
# Moved 20250222_152040M_004019.jpg -> ../data/images/processed\20250222_152040M_004019.jpg
# Class changed to: Green Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_004029.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_004029.txt
# Moved 20250222_152040M_004029.jpg -> ../data/images/processed\20250222_152040M_004029.jpg
# Class changed to: Green Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_004039.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_004039.txt
# Moved 20250222_152040M_004039.jpg -> ../data/images/processed\20250222_152040M_004039.jpg
# Class changed to: Green Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_004049.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_004049.txt
# Moved 20250222_152040M_004049.jpg -> ../data/images/processed\20250222_152040M_004049.jpg
# Class changed to: Green Light
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_004059.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_004059.txt
# Moved 20250222_152040M_004059.jpg -> ../data/images/processed\20250222_152040M_004059.jpg
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_004069.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_004069.txt
# Moved 20250222_152040M_004069.jpg -> ../data/images/processed\20250222_152040M_004069.jpg
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_004079.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_004079.txt
# Moved 20250222_152040M_004079.jpg -> ../data/images/processed\20250222_152040M_004079.jpg
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_004089.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_004089.txt
# Moved 20250222_152040M_004089.jpg -> ../data/images/processed\20250222_152040M_004089.jpg
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_004099.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_004099.txt
# Moved 20250222_152040M_004099.jpg -> ../data/images/processed\20250222_152040M_004099.jpg
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_004109.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_004109.txt
# Moved 20250222_152040M_004109.jpg -> ../data/images/processed\20250222_152040M_004109.jpg
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_004119.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_004119.txt
# Moved 20250222_152040M_004119.jpg -> ../data/images/processed\20250222_152040M_004119.jpg
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_004129.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_004129.txt
# Moved 20250222_152040M_004129.jpg -> ../data/images/processed\20250222_152040M_004129.jpg
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_004139.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_004139.txt
# Moved 20250222_152040M_004139.jpg -> ../data/images/processed\20250222_152040M_004139.jpg
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_004149.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_004149.txt
# Moved 20250222_152040M_004149.jpg -> ../data/images/processed\20250222_152040M_004149.jpg
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_004159.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_004159.txt
# Moved 20250222_152040M_004159.jpg -> ../data/images/processed\20250222_152040M_004159.jpg
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_004169.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_004169.txt
# Moved 20250222_152040M_004169.jpg -> ../data/images/processed\20250222_152040M_004169.jpg
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_004179.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_004179.txt
# Moved 20250222_152040M_004179.jpg -> ../data/images/processed\20250222_152040M_004179.jpg
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_004189.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_004189.txt
# Moved 20250222_152040M_004189.jpg -> ../data/images/processed\20250222_152040M_004189.jpg
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_004199.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_004199.txt
# Moved 20250222_152040M_004199.jpg -> ../data/images/processed\20250222_152040M_004199.jpg
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_004209.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_004209.txt
# Moved 20250222_152040M_004209.jpg -> ../data/images/processed\20250222_152040M_004209.jpg
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_004219.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_004219.txt
# Moved 20250222_152040M_004219.jpg -> ../data/images/processed\20250222_152040M_004219.jpg
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_004229.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_004229.txt
# Moved 20250222_152040M_004229.jpg -> ../data/images/processed\20250222_152040M_004229.jpg
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_004239.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_004239.txt
# Moved 20250222_152040M_004239.jpg -> ../data/images/processed\20250222_152040M_004239.jpg
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_004249.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_004249.txt
# Moved 20250222_152040M_004249.jpg -> ../data/images/processed\20250222_152040M_004249.jpg
# Viewing annotations saved to ../data/labels/viewing/viewing_20250222_152040M_004259.txt
# YOLO annotations saved to ../data/labels/formatted/20250222_152040M_004259.txt
# Moved 20250222_152040M_004259.jpg -> ../data/images/processed\20250222_152040M_004259.jpg
